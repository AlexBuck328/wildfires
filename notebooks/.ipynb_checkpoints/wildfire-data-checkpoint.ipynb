# %% [markdown]
# # Exploring Historic Wildfire Data
#
# This notebook explores historic wildfire data from 1878-2019
#
# Data can be downloaded here: [Historic Wildfires](https://www.sciencebase.gov/catalog/item/5ee13de982ce3bd58d7be7e7)

# %%
# Load desired packages

# %matplotlib inline

import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# change default figsize
plt.rcParams['figure.figsize'] = (15, 12)

# %%
# Load wildfire dataset
wf = gpd.read_file('../rawData/wildfire.geojson')

# %%
# Inspect data
wf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 65845 entries, 0 to 65844
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   FireName    65845 non-null  object
#  1   FireCode    65845 non-null  object
#  2   FireYear    65845 non-null  int64
#  3   IgntDate    65845 non-null  object
#  4   ContrlDate  65845 non-null  object
#  5   ContnDate   65845 non-null  object
#  6   Acres       65845 non-null  float64
#  7   Hectares    65845 non-null  float64
#  8   DataSrc     65845 non-null  object
#  9   DataNotes   65845 non-null  object
#  10  FireCause   65845 non-null  object
#  11  FoundIn     65845 non-null  object
#  12  FndNames    65845 non-null  object
#  13  FndCodes    65845 non-null  object
#  14  FndDates    65845 non-null  object
#  15  FireQual    65845 non-null  int64
#  16  Shape_Leng  65845 non-null  float64
#  17  Shape_Area  65845 non-null  float64
#  18  geometry    65845 non-null  geometry
# dtypes: float64(4), geometry(1), int64(2), object(12)
# memory usage: 9.5+ MB

# %%
# View data as a table
wf.head()
# Out:
#   FireName               FireCode  FireYear             IgntDate  \
# 0   414008  AK6535415457219840611      1984  1984-06-11T00:00:00
# 1   414012  AK6621715235619840618      1984  1984-06-18T00:00:00
# 2   414057  AK6495716269319840702      1984  1984-07-02T00:00:00
# 3   414060  AK6379515502919840623      1984  1984-06-23T00:00:00
# 4    ABERT  OR4258812018119840809      1984  1984-08-09T00:00:00
#
#             ContrlDate            ContnDate        Acres     Hectares  \
# 0  1899-11-30T00:00:00  1899-11-30T00:00:00  3169.156439  1282.513243
# 1  1899-11-30T00:00:00  1899-11-30T00:00:00  1964.386646   794.959774
# 2  1899-11-30T00:00:00  1899-11-30T00:00:00  1688.849283   683.453661
# 3  1899-11-30T00:00:00  1899-11-30T00:00:00  1399.226822   566.247506
# 4  1899-11-30T00:00:00  1899-11-30T00:00:00  7945.460289  3215.416542
#
#                               DataSrc  \
# 0  Monitoring Trends in Burn Severity
# 1  Monitoring Trends in Burn Severity
# 2  Monitoring Trends in Burn Severity
# 3  Monitoring Trends in Burn Severity
# 4  Monitoring Trends in Burn Severity
#
#                                            DataNotes           FireCause  \
# 0  First Tier Wildfires, polygon with largest acr...  No cause indicated
# 1  First Tier Wildfires, polygon with largest acr...  No cause indicated
# 2  First Tier Wildfires, polygon with largest acr...  No cause indicated
# 3  First Tier Wildfires, polygon with largest acr...  No cause indicated
# 4  First Tier Wildfires, polygon with largest acr...  No cause indicated
#
#                                              FoundIn  \
# 0  Alternate Fire Sources: Monitoring Trends in B...
# 1  Alternate Fire Sources: Monitoring Trends in B...
# 2  Alternate Fire Sources: Monitoring Trends in B...
# 3  Alternate Fire Sources: Monitoring Trends in B...
# 4  Alternate Fire Sources: BLM National Fire Peri...
#
#                                     FndNames  \
# 0               Alternate Fire Names: 414008
# 1               Alternate Fire Names: 414012
# 2               Alternate Fire Names: 414057
# 3               Alternate Fire Names: 414060
# 4  Alternate Fire Names: Abert, Abert, ABERT
#
#                                             FndCodes  \
# 0        Alternate Fire Codes: AK6535415457219840611
# 1        Alternate Fire Codes: AK6621715235619840618
# 2        Alternate Fire Codes: AK6495716269319840702
# 3        Alternate Fire Codes: AK6379515502919840623
# 4  Alternate Fire Codes: M053, M053, OR4258812018...
#
#                                             FndDates  FireQual    Shape_Leng  \
# 0  Alternate Ignition, Controlled, and Contained ...         1  22876.846278
# 1  Alternate Ignition, Controlled, and Contained ...         1  17290.576444
# 2  Alternate Ignition, Controlled, and Contained ...         1  11226.497241
# 3  Alternate Ignition, Controlled, and Contained ...         1  18047.888216
# 4  Alternate Ignition, Controlled, and Contained ...         1  73017.681929
#
#      Shape_Area                                           geometry
# 0  1.282513e+07  POLYGON ((-2729116.221 3783619.593, -2729145.4...
# 1  7.949598e+06  POLYGON ((-2587275.964 3793164.935, -2587865.3...
# 2  6.834537e+06  POLYGON ((-3073104.885 3996965.523, -3073150.9...
# 3  5.662475e+06  POLYGON ((-2841528.411 3660892.172, -2841529.3...
# 4  3.215417e+07  POLYGON ((-1839066.540 551133.989, -1839017.70...

# %%
# Avreage fire size (AC) per year
ACyear = wf.groupby('FireYear').Acres.mean()

ACyear
# Out:
# FireYear
# 1878    49323.898711
# 1889     9248.857692
# 1890     2844.077359
# 1893     5809.187171
# 1894    10274.898434
#             ...
# 2015     5350.126563
# 2016     2986.744162
# 2017     4246.361276
# 2018     3871.330894
# 2019     2826.651948
# Name: Acres, Length: 128, dtype: float64

# %%
fireYear = wf.groupby('FireYear').mean()

fireYear
# Out:
#                  Acres      Hectares  FireQual    Shape_Leng    Shape_Area
# FireYear
# 1878      49323.898711  19960.691274  2.000000  83183.890560  1.996069e+08
# 1889       9248.857692   3742.883224  2.000000  37081.849381  3.742883e+07
# 1890       2844.077359   1150.958290  2.000000  19305.894841  1.150958e+07
# 1893       5809.187171   2350.896720  2.000000  29773.174526  2.350897e+07
# 1894      10274.898434   4158.107548  2.000000  31726.465449  4.158108e+07
# ...                ...           ...       ...           ...           ...
# 2015       5350.126563   2165.121318  1.625372  23941.254070  2.165121e+07
# 2016       2986.744162   1208.693548  1.672070  16911.940201  1.208694e+07
# 2017       4246.361276   1718.442959  1.666930  21826.336879  1.718443e+07
# 2018       3871.330894   1566.673414  2.000000  14836.205726  1.566673e+07
# 2019       2826.651948   1143.906470  2.000000  13606.805111  1.143906e+07
#
# [128 rows x 5 columns]

# %%
year = datetime.datetime.today().year
YEARS = [year - i for i in range(144)]
wfYears = YEARS[2:144]
wfYears
# Out:
# [2019,
#  2018,
#  2017,
#  2016,
#  2015,
#  2014,
#  2013,
#  2012,
#  2011,
#  2010,
#  2009,
#  2008,
#  2007,
#  2006,
#  2005,
#  2004,
#  2003,
#  2002,
#  2001,
#  2000,
#  1999,
#  1998,
#  1997,
#  1996,
#  1995,
#  1994,
#  1993,
#  1992,
#  1991,
#  1990,
#  1989,
#  1988,
#  1987,
#  1986,
#  1985,
#  1984,
#  1983,
#  1982,
#  1981,
#  1980,
#  1979,
#  1978,
#  1977,
#  1976,
#  1975,
#  1974,
#  1973,
#  1972,
#  1971,
#  1970,
#  1969,
#  1968,
#  1967,
#  1966,
#  1965,
#  1964,
#  1963,
#  1962,
#  1961,
#  1960,
#  1959,
#  1958,
#  1957,
#  1956,
#  1955,
#  1954,
#  1953,
#  1952,
#  1951,
#  1950,
#  1949,
#  1948,
#  1947,
#  1946,
#  1945,
#  1944,
#  1943,
#  1942,
#  1941,
#  1940,
#  1939,
#  1938,
#  1937,
#  1936,
#  1935,
#  1934,
#  1933,
#  1932,
#  1931,
#  1930,
#  1929,
#  1928,
#  1927,
#  1926,
#  1925,
#  1924,
#  1923,
#  1922,
#  1921,
#  1920,
#  1919,
#  1918,
#  1917,
#  1916,
#  1915,
#  1914,
#  1913,
#  1912,
#  1911,
#  1910,
#  1909,
#  1908,
#  1907,
#  1906,
#  1905,
#  1904,
#  1903,
#  1902,
#  1901,
#  1900,
#  1899,
#  1898,
#  1897,
#  1896,
#  1895,
#  1894,
#  1893,
#  1892,
#  1891,
#  1890,
#  1889,
#  1888,
#  1887,
#  1886,
#  1885,
#  1884,
#  1883,
#  1882,
#  1881,
#  1880,
#  1879,
#  1878]

# %%
# create a figure and increase the size 
fig, ax = plt.subplots(figsize=(25, 15))

ax.bar(wfYears, ACyear);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-8841be4d00f4> in <module>
#       2 fig, ax = plt.subplots(figsize=(25, 15))
#       3
# ----> 4 ax.bar(wfYears, ACyear);
#
# /usr/local/Caskroom/miniconda/base/envs/wildfires/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/Caskroom/miniconda/base/envs/wildfires/lib/python3.7/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2430         x, height, width, y, linewidth = np.broadcast_arrays(
#    2431             # Make args iterable too.
# -> 2432             np.atleast_1d(x), height, width, y, linewidth)
#    2433
#    2434         # Now that units have been converted, set the tick locations.
#
# <__array_function__ internals> in broadcast_arrays(*args, **kwargs)
#
# /usr/local/Caskroom/miniconda/base/envs/wildfires/lib/python3.7/site-packages/numpy/lib/stride_tricks.py in broadcast_arrays(subok, *args)
#     256     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     257
# --> 258     shape = _broadcast_shape(*args)
#     259
#     260     if all(array.shape == shape for array in args):
#
# /usr/local/Caskroom/miniconda/base/envs/wildfires/lib/python3.7/site-packages/numpy/lib/stride_tricks.py in _broadcast_shape(*args)
#     187     # use the old-iterator because np.nditer does not handle size 0 arrays
#     188     # consistently
# --> 189     b = np.broadcast(*args[:32])
#     190     # unfortunately, it cannot handle 32 or more arguments directly
#     191     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape
